# %% [markdown]
# <a href="https://colab.research.google.com/github/carolmontesanti-glitch/p.a-1c--grupo-a/blob/main/aula_P_A_27_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# interações e laços de repetição

for i in range (5):
  print("Olá mundo")
# Out:
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo

# %%
for i in range (1, 6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#escrever um programa q imprime de 5 até 0

for i in range (6):
  print(6 - i)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# escrever um programa q imprime os numeros pares de0 a 10

for i in range(0, 11, 2):
    print(i)

# usando if:
#for i in range (11):
#   if i % 2 == 0:
#     print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#imprime os numeros impares
for i in range (1, 11, 2):
  print(i)

# %%
#escrever um programa que o usuario digita o numero de 1 a 10 e imprime a tabuada
digito1 = int(input("digite um numero de 1 a 10: "))

for i in range (1, 11):
  calc = digito1 * i
  print(f"{digito1} x {i} = {calc}")
# Out:
# digite um numero de 1 a 10: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
