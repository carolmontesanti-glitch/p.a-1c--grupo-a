# %% [markdown]
# <a href="https://colab.research.google.com/github/carolmontesanti-glitch/p.a-1c--grupo-a/blob/main/helloworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
nome=("Carol") #str
print(f"meu nome é {nome}")
altura=1.56
print(f"minha altura é {altura}")
idade=15
print(f"eu tenho {idade} anos")

#complex
complexo= 2 + 3j

#bool
new_var = False
estachovendo = new_var
# Out:
# meu nome é Carol
# minha altura é 1.56
# eu tenho 15 anos

# %%
#entrada
lado = 6
#processamento
quadrado = lado * lado
#saida
print(f"o total da area do quadrado é {quadrado}")
# Out:
# o total da area do quadrado é 36

# %%
altura = 6
largura = 5
area = altura * largura
print(f"a area da sala de aula é {area}")
# Out:
# a area da sala de aula é 30

# %%
nota1 = float(input("digite a primeira nota:"))
nota2 = float(input("digite a segunda nota:"))
nota3 = float(input("digite a terceira nota:"))
nota4 = float(input("digite a quarta nota:"))
media = (nota1 + nota2 + nota3 + nota4) / 4
print(f"a média é {media}")

if media >= 5:
  print("passou de ano!")
else:
  print("vgoce ficou de recuperação!")
# Out:
# digite a primeira nota:3
# digite a segunda nota:6
# digite a terceira nota:8
# digite a quarta nota:3
# a média é 5.0
# passou de ano!

# %%
valor = 2
dobro = valor * 2
print(f"o dobro é {dobro}")
# Out:
# o dobro é 4

# %%
# fazer um cadastro simples c nome  do usuario e idade, o prgrama dara uma msg de boas vindas
usuario = str(input("digite seu nome:"))
idade = int(input("digite sua idade: "))
print(f"Olá {usuario}, seja bem vindo!")
print(f"voce tem {idade} anos.")
# Out:
# digite seu nome:Carol
# digite sua idade: 15
# Olá Carol, seja bem vindo!
# voce tem 15 anos.

# %%
# fazer um programa que converte a temperatura de celsius para firhrenheit.

gc = float(input("digite a temperatura em graus celsius: "))
conv = (gc * 9/5) + 32
print(f"a temperatura em firhrenheit é {conv}")
# Out:
# digite a temperatura em graus celsius: 26
# a temperatura em firhrenheit é 78.8

# %%
#soma de 2 numeros
a = int(input("digite o primeiro numero: "))
b = int(input("digite o segundo numero: "))
soma = a + b
print(f"a soma de {a} mais {b} é igual a: {soma}")

subt = a - b
print(f"a diferença de {a} menos {b} é igual a: {subt}")

mult = a * b
print(f"{a} vezes {b} é igual a {mult}")

divsao = a // b
print(f"a divisao de {a} por {b} é {divsao}")

resto = a % b
print(f"o resto é igual a {resto}")
# Out:
# digite o primeiro numero: 12
# digite o segundo numero: 6
# a soma de 12 mais 6 é igual a: 18
# a diferença de 12 menos 6 é igual a: 6
# 12 vezes 6 é igual a 72
# a divisao de 12 por 6 é 2
# o resto é igual a 0

# %%
# operadores relacionais
num1 = int(input("digite o primeiro numero "))
num2 = int(input("digite o segundo numero "))

igual = num1 == num2
maior = num1 > num2
menor = num1 < num2
menorigual = num1 <= num2
maiorigual = num1 >= num2

print(igual)
print(maior)
print(menor)
print(menorigual)
print(maiorigual)
# Out:
# digite o primeiro numero 497408789
# digite o segundo numero 64598096095
# False
# False
# True
# True
# False

# %%
a = int(input("digite um numero "))
b = int(input("digite um numero "))
if a > b:
  print(f"{a} maior que {b}")
else:
  print(f"{b} maior que {a}")
# Out:
# digite um numero 2
# digite um numero 4
# 4 maior que 2

# %%
user = str(input("digite seu nome: "))
idd = int(input("digite sua idade: "))

if idd > 18:
  print(f"{user} voce é maior de idade")
else:
  print(f"{user} voce é menor de idade")
# Out:
# digite seu nome: Carol
# digite sua idade: 15
# Carol voce é menor de idade

# %%
num = int(input("digite um numero"))
div = num % 2

if div == 0:
  print(f"{num} é par ")
else:
  print(f"{num} é impar")
# Out:
# digite um numero4
# 4 é par

# %%
senha = int(input("digite sua senha"))
if senha == 1234:
  print("acesso permitido")
else:
  print("acesso negado")
# Out:
# digite sua senha1235
# acesso negado

# %%
num = int(input("digite um numero: "))
if num > 10:
  print(f"{num} é maior que 10")
else:
  print(f"{num} é menor que 10")
# Out:
# digite um numero: 11
# 11 é maior que 10

# %%
compra = int(input("digite o valor da compra: "))
if compra > 100:
  div = compra - (compra * 0.10)
  print("voce tem desonto")
else:
  print("voce nao tem desconto")
# Out:
# digite o valor da compra: 125
# voce tem desonto

# %%
print("|--------CALCULADORA-----------|")
print("|                              |")
print("|-------------MENU-------------|")
print("|soma =                       1|")
print("|subtração =                  2|")
print("|multiplicação =              3|")
print("|divisão =                    4|")


dig = int(input("digite qual operação voce quer usar"))

a = int(input("digite o primeiro numero: "))
b = int(input("digite o segundo numero: "))

if dig == 1:
  print(f"a soma dos numeros é igual a: {a + b}")
if dig == 2:
  print(f"a subtração dos numeros é igual a: {a - b}")
if dig == 3:
  print(f"a multiplicacao dos numeros é igual a: {a * b}")
if dig == 4:
  print(f"a divisao dos numeros é igual a: {a / b}")
# Out:
# |--------CALCULADORA-----------|
# |                              |
# |-------------MENU-------------|
# |soma =                       1|
# |subtração =                  2|
# |multiplicação =              3|
# |divisão =                    4|
# digite qual operação voce quer usar4
# digite o primeiro numero: 8
# digite o segundo numero: 7
# a divisao dos numeros é igual a: 1.1428571428571428

# %%
# Programa que classifica os tipos de triangulos:
#isoceles
#equilarero
#Escaleno

l1 = int(input("Digite o primeiro lado do triangulo: "))
l2 = int(input("Digite o segundo lado do triangulo: "))
l3 = int(input("Digite o terceiro lado do triangulo: "))

if l1 == l2 and l2 == l3:
    print("O triangulo é equilatero")

if l1 != l2 and l2 != l3 and l1 != l3:
    print("O triangulo é escaleno")

if (l1 == l2 or l2 == l3 or l1 == l3) and (l1 != l2 or l2 != l3 or l1 != l3):
    print("O triangulo é isoceles")
